# %%
week1_ml

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("Environment ready. Let's go.")
# Out:
# Environment ready. Let's go.

# %%
#I have learnt about vectors. This matters in ML because it give an understanding in movement in space which can be manipulated using numbers. It is basically a language that defines space using numbers.

# %%
#i have learnt about linear combinations. This matters in ML because it gives an understanding that scalars can be added amounting in larger coordinate systems in space. This can be used in defining algorithms on far machines can stretch or move in space or on 2D bases.

# %%
#matrix multiplication matters in ML because it brings the concept of multiple linear transformations bringing in the aspect of complex movement in space in many different directions.

# %%
#3 dimensional linear transformation matters in ML because one can describe movement of a machine in 3D space using numbers.

# %%
#The determinant matters in ML because a single numbe can be used to manipulate movement in space allowing easy control of machines.

# %%
import numpy as np

# Vectors
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
print("Dot product:", np.dot(a, b))

# Matrix multiplication
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
print("Matrix multiply:\n", np.matmul(A, B))
# Out:
# Dot product: 32
# Matrix multiply:
#  [[19 22]
#  [43 50]]
